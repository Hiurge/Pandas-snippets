# %%
# Pandas snippet for quick linear plotting 
# & also quick euro-pln tax calc
import pandas as pd

# %%
title="Euro to PLN taxed" 
invest_euro, euro_to_pln = range(1500, 4500, 100), 4.28
invest_pln = [ euro*euro_to_pln for euro in invest_euro]
taxed_pln = lambda x: [ s*x for s in InPLN]
tax_str = lambda x: str(round(abs(x-1),2)*100)
tax_name = lambda x: ''.join(['Taxed ', tax_str(x),'%']) if x < 1 else "Tax Covered"
taxed = [(tax_name(tax), taxed_pln(tax)) for tax in [1.0, 0.85, 0.82, 0.81, 0.68]]
pd.DataFrame(data=dict(taxed),index=invest_euro).plot.line(title=title).set_xlabel("Euro")
# Out:
# Text(0.5,0,'Euro')
