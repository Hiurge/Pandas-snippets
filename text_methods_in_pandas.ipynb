# %%
# TEXT METHODS in Pandas.
import pandas as pd
from IPython.display import display, HTML

# %%
Methods_Descriptions = [ (s.split('\t')) for s in open('pandasmethods.txt', "r").read().split('\n')[1:] ]
df = pd.DataFrame(Methods_Descriptions ,columns=['Method','Description'], dtype='str')
df.style.set_properties(**{'text-align' : 'left'})
# Out:
# <style  type="text/css" >
#     #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row0_col0 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row0_col1 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row1_col0 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row1_col1 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row2_col0 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row2_col1 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row3_col0 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row3_col1 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row4_col0 {
#             text-align:  left;
#         }    #T_b29713cc_f8ed_11e8_9a77_4b7075499ae1row4_col1 {
# ...

# %%
#display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Method</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cat()</td>
#       <td>Concatenate strings</td>
#     </tr>
#     <tr>
#       <td>split()</td>
#       <td>Split strings on delimiter</td>
#     </tr>
#     <tr>
#       <td>rsplit()</td>
#       <td>Split strings on delimiter working from the en...</td>
#     </tr>
#     <tr>
#       <td>get()</td>
#       <td>Index into each element (retrieve i-th element)</td>
#     </tr>
#     <tr>
#       <td>join()</td>
#       <td>Join strings in each element of the Series wit...</td>
#     </tr>
#     <tr>
#       <td>get_dummies()</td>
#       <td>Split strings on the delimiter returning DataF...</td>
#     </tr>
#     <tr>
#       <td>contains()</td>
#       <td>Return boolean array if each string contains p...</td>
#     </tr>
#     <tr>
#       <td>replace()</td>
# ...
